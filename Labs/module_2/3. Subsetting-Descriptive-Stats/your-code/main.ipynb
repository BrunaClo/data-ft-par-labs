# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
# import libraries here
import os
os.chdir(r'C:\Users\bruna\IronHack\GitHub\data-ft-par-labs\Labs\data')

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv('Temp_states.csv')

# %% [markdown]
# #### Print `temp`.

# %%
temp.shape
# Out:
# (7, 3)

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
print(f"""The data type of the the column City is :
{temp.City}""")

print(f"""\nThe data type of the the column State is :
{temp.State}""")

print(f"""\nThe data type of the the column Temperature is :
{temp.Temperature}""")
# Out:
# The data type of the the column City is :
# 0           NYC
# 1        Albany
# 2       Buffalo
# 3      Hartford
# 4    Bridgeport
# 5        Treton
# 6        Newark
# Name: City, dtype: object
#
# The data type of the the column State is :
# 0       New York
# 1       New York
# 2       New York
# 3    Connecticut
# 4    Connecticut
# 5     New Jersey
# 6     New Jersey
# Name: State, dtype: object
#
# The data type of the the column Temperature is :
# 0    19.444444
# 1     9.444444
# 2     3.333333
# 3    17.222222
# 4    14.444444
# 5    22.222222
# 6    20.000000
# Name: Temperature, dtype: float64

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
ny = temp.loc[temp.State=='New York']
ny
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
round(ny.Temperature.mean(),2)
# Out:
# 10.74

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp.loc[temp['Temperature']>15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
temp.loc[temp['Temperature']>15, ['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp.loc[(temp['Temperature']>15)& (temp['Temperature']<20), ['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
temp.groupby('State').Temperature.describe().round(2).T
# Out:
# State  Connecticut  New Jersey  New York
# count         2.00        2.00      3.00
# mean         15.83       21.11     10.74
# std           1.96        1.57      8.13
# min          14.44       20.00      3.33
# 25%          15.14       20.56      6.39
# 50%          15.83       21.11      9.44
# 75%          16.53       21.67     14.44
# max          17.22       22.22     19.44

# %%
temp.groupby('State').mean().round(2)
# Out:
#              Temperature
# State
# Connecticut        15.83
# New Jersey         21.11
# New York           10.74

# %%
temp.groupby('State').std().round(2)
# Out:
#              Temperature
# State
# Connecticut         1.96
# New Jersey          1.57
# New York            8.13

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('Employees.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.head()
# Out:
#   Department Education      Title      Name  Years  Salary
# 0      Admin    Master  associate     David      4      58
# 1         IT    Master  associate    Thomas      7      45
# 2      Admin    Master  associate     Diana     10      52
# 3      Admin    Master         VP  Manuella     15      33
# 4      Sales    Master    Analyst     Carla      6      38

# %%
employees.shape
# Out:
# (500, 6)

# %%
employees.describe().round(2).T
# Out:
#         count   mean    std   min   25%   50%    75%    max
# Years   500.0   7.56   4.47   1.0   3.0   7.0  11.25   15.0
# Salary  500.0  73.53  26.89  30.0  50.0  72.0  97.00  120.0

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
round(employees.Salary.mean(),2)
# Out:
# 73.53

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
round(employees.Salary.max(),2)
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
round(employees.Salary.min(),2)
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees[employees['Salary'] == employees['Salary'].min()]
# Out:
#     Department Education      Title      Name  Years  Salary
# 27          IT  Bachelor    Analyst      Sean     12      30
# 106      Admin  Bachelor  associate      Luke      4      30
# 128      Sales       PhD         VP      Adam      8      30
# 139      Sales       PhD    Analyst      Rick     11      30
# 214      Sales    Master         VP      Neil     11      30
# 266         HR       PhD  associate    Marcel     10      30
# 452         IT  Bachelor    Analyst  Augustin     13      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees.loc[employees.Name=='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees.loc[employees.Name=='David', ['Salary']]
# Out:
#      Salary
# 0        58
# 124      31

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees[employees.Title == 'associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here
employees.loc[:2]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 3
# your code here
employees.iloc[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 4
# your code here
employees[:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees.loc[(employees['Title']=='associate') & (employees['Salary']>55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby(['Years'])[['Salary']].mean().round(2)
# Out:
#        Salary
# Years
# 1       75.86
# 2       75.86
# 3       74.57
# 4       77.13
# 5       73.86
# 6       72.38
# 7       73.84
# 8       64.25
# 9       76.74
# 10      73.35
# 11      74.87
# 12      73.45
# 13      71.94
# 14      70.97
# 15      69.76

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby('Title')[['Salary']].mean().round(2)
# Out:
#            Salary
# Title
# Analyst     73.70
# VP          72.91
# associate   73.97

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees['Salary'].describe().round(2).T
# Out:
# count    500.00
# mean      73.53
# std       26.89
# min       30.00
# 25%       50.00
# 50%       72.00
# 75%       97.00
# max      120.00
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees.groupby('Department').describe().round(2).select_dtypes(include=['number'])
# Out:
#             Years                                         Salary         \
#             count  mean   std  min   25%  50%   75%   max  count   mean
# Department
# Admin       123.0  7.64  4.71  1.0  3.00  8.0  12.0  15.0  123.0  76.33
# HR          122.0  7.17  4.29  1.0  3.25  6.0  11.0  15.0  122.0  74.24
# IT          134.0  8.14  4.47  1.0  4.00  8.5  12.0  15.0  134.0  70.67
# Sales       121.0  7.21  4.36  1.0  3.00  7.0  11.0  15.0  121.0  73.13
#
#
#               std   min    25%   50%    75%    max
# Department
# Admin       25.73  30.0  53.50  78.0  98.00  120.0
# HR          26.52  30.0  50.25  74.5  96.00  119.0
# IT          27.41  30.0  46.25  69.0  97.75  120.0
# Sales       27.82  30.0  49.00  69.0  95.00  120.0

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here
employees.groupby('Department').apply(lambda x : x.Salary.max() - x.Salary.min())
# Out:
# Department
# Admin    90
# HR       89
# IT       90
# Sales    90
# dtype: int64

# %%
employees.groupby('Department').agg({'Salary' : lambda x: x.max() - x.min()})
# Out:
#             Salary
# Department
# Admin           90
# HR              89
# IT              90
# Sales           90

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv("Orders.csv")

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
round(orders.amount_spent.mean(),2)
# Out:
# 22.39

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
round(orders.amount_spent.max(),2)
# Out:
# 168469.6

# %%
round(orders.amount_spent.min(),2)
# Out:
# 0.0

# %%
orders.describe().round(2).T
# Out:
#                  count       mean        std       min        25%        50%  \
# Unnamed: 0    397924.0  278465.22  152771.37       0.0  148333.75  284907.50
# InvoiceNo     397924.0  560617.13   13106.17  536365.0  549234.00  561893.00
# year          397924.0    2010.93       0.25    2010.0    2011.00    2011.00
# month         397924.0       7.61       3.42       1.0       5.00       8.00
# day           397924.0       3.61       1.93       1.0       2.00       3.00
# hour          397924.0      12.73       2.27       6.0      11.00      13.00
# Quantity      397924.0      13.02     180.42       1.0       2.00       6.00
# UnitPrice     397924.0       3.12      22.10       0.0       1.25       1.95
# CustomerID    397924.0   15294.32    1713.17   12346.0   13969.00   15159.00
# amount_spent  397924.0      22.39     309.06       0.0       4.68      11.80
#
#                     75%        max
# Unnamed: 0    410079.25  541908.00
# InvoiceNo     572090.00  581587.00
# ...

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
spanish_customers = pd.Series(orders.loc[orders.Country=='Spain']['CustomerID'].unique())

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
spanish_customers.shape
# Out:
# (30,)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
customers_total_quantity = orders.groupby('CustomerID').sum()

# %%
customers_more_50 = pd.Series(customers_total_quantity[customers_total_quantity['Quantity'] > 50].index);
customers_more_50
# Out:
# 0       12346
# 1       12347
# 2       12348
# 3       12349
# 4       12350
#         ...
# 4086    18278
# 4087    18281
# 4088    18282
# 4089    18283
# 4090    18287
# Name: CustomerID, Length: 4091, dtype: int64

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
orders.loc[(orders.Quantity>50) & (orders.Country=='Spain')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
orders.loc[orders.amount_spent==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
orders[orders.Description.str.startswith('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[(orders.Description.str.startswith('lunch bag')) & (orders.year == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
orders[orders['Country'] == 'Spain']['amount_spent'].hist(bins=50)
plt.show()

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
orders[orders.month == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders[orders['month'] == 8]['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby('Country').amount_spent.mean().round(2)
# Out:
# Country
# Australia               116.90
# Austria                  25.62
# Bahrain                  32.26
# Belgium                  20.28
# Brazil                   35.74
# Canada                   24.28
# Channel Islands          27.34
# Cyprus                   22.13
# Czech Republic           33.07
# Denmark                  49.88
# EIRE                     36.69
# European Community       21.67
# Finland                  32.91
# France                   25.06
# Germany                  25.31
# Greece                   32.83
# Iceland                  23.68
# Israel                   29.12
# Italy                    23.06
# Japan                   116.56
# Lebanon                  37.64
# Lithuania                47.46
# Malta                    24.34
# Netherlands             120.80
# Norway                   33.74
# Poland                   22.23
# Portugal                 22.87
# RSA                      17.28
# Saudi Arabia             16.21
# Singapore                95.85
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders.UnitPrice.max()
# Out:
# 8142.75

# %%
orders.groupby('Description').UnitPrice.max().sort_values(ascending = False)
# Out:
# Description
# postage                               8142.750
# manual                                4161.060
# dotcom postage                        1599.260
# picnic basket wicker 60 pieces         649.500
# vintage blue kitchen cabinet           295.000
#                                         ...
# folding camping scissor w/knif & s       0.120
# mini highlighter pens                    0.120
# wrap bad hair day                        0.100
# porcelain budah incense holder           0.100
# pads to match all cushions               0.001
# Name: UnitPrice, Length: 3877, dtype: float64

# %%
orders[orders['UnitPrice'] == orders['UnitPrice'].max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby('year').amount_spent.mean().round(2)
# Out:
# year
# 2010    21.89
# 2011    22.43
# Name: amount_spent, dtype: float64

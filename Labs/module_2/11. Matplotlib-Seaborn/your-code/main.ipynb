# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
os.chdir(r'C:\Users\bruna\IronHack\GitHub\data-ft-par-labs\Labs\data')

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig, ax = plt.subplots(1,2, sharey = False, figsize = (15,6))
ax[0].plot(x, y, lw=3, color='g')

ax[1].plot(x, z, lw=3, color='r')

plt.show()

# %%
# Method 2
fig, ax = plt.subplots(1,2, sharey = True, figsize = (15,6))
ax[0].plot(x, y, lw = 3, color='g')
ax[1].set_title('Sharing Y axis')
ax[0].set_ylabel("I'm Y axis")
ax[1].plot(x, z, lw=3, color='r')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=True)
fig.set_figwidth(15)
fig.set_figheight(6)
ax[0].plot(x, y, lw = 3, color = 'g')
ax[0].set_title('Sharing Y axis')
ax[1].plot(x, z, lw = 3, color='r')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharey=True)
ax[0].plot(x, y, lw = 3, color = 'g')
ax[0].set_title('Sharing Y axis')
ax[1].plot(x, z, lw = 3, color='r')
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
# Method 1
fig, ax = plt.subplots(1,2, figsize =(15,5), sharey = True, gridspec_kw=dict(width_ratios=[2, 4]))
ax[0].grid()
ax[1].grid()
ax[0].plot(x, y)
ax[1].set_title('Sharing Y axis', fontweight='bold', fontsize=15, loc = 'left', fontname = 'Times New Roman')
ax[1].plot(x, y, z)
ax[0].set_ylabel("I'm Y axis", fontweight='bold', fontsize=15, loc = 'bottom', fontname = 'Times New Roman')
fig.tight_layout()
plt.show()

# %%
# your code here
# Method 1
fig, ax = plt.subplots(1,2, figsize =(15,5), sharey = False, gridspec_kw=dict(width_ratios=[2, 3]))
ax[0].grid()
ax[1].grid()
ax[0].plot(x, y)
ax[1].set_title('NOT Sharing Y axis', fontweight='bold', fontsize=15, loc = 'left', fontname = 'Times New Roman')
ax[1].plot(x, y, z)
ax[0].set_ylabel("I'm Y axis", fontweight='bold', fontsize=15, loc = 'top', fontname = 'Times New Roman')
ax[1].set_ylabel("I'm also Y axis", fontweight='bold', fontsize=15, loc = 'bottom', fontname = 'Times New Roman')
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
fig, ax = plt.subplots(1,2, figsize =(15,5))
fig.tight_layout(pad = 5.0)

# the first plot :
ax[0].plot(x, x**2, x, np.exp(x))
ax[0].set_ylabel("I'm normal Y axis", fontweight = 'bold', fontsize = 12, fontname = 'times new roman', loc = 'top')
ax[0].grid()

#the second plot:
ax[1].set_yscale('log')
ax[1].set_ylabel("I'm log Y axis", fontweight = 'bold', fontsize = 12, fontname = 'times new roman', loc = 'top')
ax[1].plot(x, x**2, x,np.exp(x))
ax[1].grid()


# tto show this plot
plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# your code here
fig, ax = plt.subplots(1,2, figsize =(15,5))
fig.tight_layout(pad = 5.0)


# the first plot :
ax[0].plot(x, x**2, label = 'x**2')
ax[0].plot(x, np.exp(x),label = 'exp(x)')
ax[0].set_ylabel("I'm normal Y axis", fontweight = 'bold', fontsize = 12, fontname = 'times new roman', loc = 'top')
ax[0].set_title("Normal scale")
ax[0].grid('--')
ax[0].legend()

#the second plot:
ax[1].set_yscale('log')
ax[1].set_ylabel("I'm log Y axis", fontweight = 'bold', fontsize = 12, fontname = 'times new roman', loc = 'top')
ax[1].plot(x, x**2, label = 'x**2')
ax[1].plot(x, np.exp(x), label = 'exp(x)')
ax[1].set_title("Logarithmic scale (y)")
ax[1].grid('-.')
ax[1].legend()

# to show this plot
plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
import seaborn as sns

# %%
month_steps = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()
wk_steps = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median().sort_values()

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1,2, figsize = (12,4))

# Set the current axes instance to ax[0] - Now plt methods will affect ax[0]
plt.sca(ax[0])

# Plot the weekday steps in the current axes
month_steps.plot(kind = 'line',linewidth=2)

# Add labels, title, etc
plt.ylabel('Median number of steps')
plt.xlabel('Months')
plt.title('Median Steps walked by month')
plt.xticks(range(13), ['','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

# MEDIAN STEPS BY WORK_OR_WEEKEND
# Set the current axes instance to ax[1] - Now plt methods will affect ax[1]
plt.sca(ax[1])

# your code here
wk_steps.plot(kind='bar', alpha=0.7)
plt.xlabel('Weekdays')
plt.ylabel('Median number of steps')
plt.title('Median Steps walked by Workdays and Weekend')
plt.xticks(range(2), ['Weekend','Workdays'], rotation = 0)
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
for i in fitbit[['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']]:
    plt.figure(figsize=(8,6))
    sns.scatterplot(data = fitbit, x =i, y = 'Steps')
    plt.title(f'Steps by {i}')
    plt.show()

# %%
# Create a df with the columns we are interested in 
cols = ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary','Steps']
df = fitbit[cols]

# Create a figure of a fixed size and axes
f, ax = plt.subplots(1, 3, figsize = (20,8))

# Iterate to draw each scatter plot
for i in range(3):
    plt.sca(ax[i])
    plt.scatter(df[cols[i]], df[cols[3]], color = 'darkblue')
    plt.xlabel(df[cols[i]].name)
    plt.ylabel('Steps')

# %%
f, ax = plt.subplots(1, 3, figsize = (20,8))

# Iterate to draw each scatter plot
for i in range(3):
    ax[i].scatter(df[cols[i]], df[cols[3]], color = 'r')
    ax[i].set_xlabel(df[cols[i]].name)
    ax[i].set_ylabel('Steps')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes('float', 'int').dtypes
# Out:
# Survived    float64
# Age         float64
# Fare        float64
# dtype: object

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes('object').dtypes
# Out:
# Name        object
# Gender      object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# your code here
plt.style.use('seaborn-dark-palette') 

sns.set_style('dark') 

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].hist(bins=30)

# Set titles, labels, etc
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

f, ax = plt.subplots(1,3)

f.set_figwidth(15)
bins = [10, 20, 50]

# Plot the histogram using a different number of bins
for i in range(3):
    plt.sca(ax[i])
    titanic['Age'].hist(bins=bins[i])
    plt.title('Age Histogram by ' + str(bins[i])+' bins')
    plt.xlabel('Age')
    plt.ylabel('Count')

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# `Answer` :
#
#     Using a low number of bins (wider bins) reduces noise on the distribution estimation while using a
#     high number of bins (narrower bins) gives greater precision to the distribution estimation (and more noise).
#     With larger bins we can see that it's not a prefect distribution.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic['Age'], bins = 30, kde = True, color = 'red')
plt.title('Age Histogram')
# Show the plot
plt.show()
# Out:
# C:\Users\bruna\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic['Gender'].value_counts().plot(kind='bar')

# Add labels to the plot and change xticks rotation
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation = 0)

# Show the plot
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x ='Gender', data = titanic)

# Show the plot
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.countplot(titanic.Pclass)
plt.show()
# Out:
# C:\Users\bruna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic['Pclass'].value_counts().plot(kind='bar')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(data = titanic, y = 'Age', orient='v', width=0.3)
plt.show()

# %%
titanic.boxplot(column='Age')
plt.show()

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %% [markdown]
# `Answer :`
#
#     The statistics that you can get from the boxplot are the minimum, first quartile, median,
#     third quartile, and maximum.
#
#     The red line shows us the median of Age.
#     The blue box shows us the interquartile range (from Q1 to Q3).
#     It also shows us the outliers, which are out of the maximum and minimum range (Q1 - 1.5*IQR, Q3 + 1.5*IQR).

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# Violin plot
sns.violinplot(data = titanic, y="Age", width=0.5, color='darkred')
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %% [markdown]
# `Answer:`
#
#     This plot is a combination of a boxplot and a density plot. The violin plot features a kernel density estimation
#     of the underlying distribution of the data.
#
#     The black central part of the plot is the same as a boxplot and the white dot is the median.
#     The dark red part is the distribution of the data.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic['Age'], titanic['Fare'], color='darkgreen')

plt.ylabel('Fare')
plt.xlabel('Age')

plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(titanic['Age'], titanic['Fare'], color='lightgreen')

plt.ylabel('Fare')
plt.xlabel('Age')

plt.show()
# Out:
# C:\Users\bruna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
# Correlation matrix
sns.heatmap(titanic.corr(), cmap='ocean_r', annot=True)

# Add title
plt.title('Correlation matrix')

# Show plot
plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %% [markdown]
# `Answer:`
#
#     The most correlated features are SibSp and Parch.

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
# Boxplot
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')

# Show the plot
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
dist_age_g = sns.FacetGrid(data = titanic, col = 'Gender')
dist_age_g.map(plt.hist, 'Age')
plt.show()
